# %%
print("hello colab")
# Out:
# hello colab

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train(1).csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df2 = df.fillna(method='ffill',axis=1)

# %%
df2.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# داده های گمشده رو با فوروارد فیل جایگزین کردیم تا داده ی گمشده ای نداشته باشیم و دیتا فریم رو داخل دیتافریم 2 ریختم و در ادامه یک خرده تمرین برای پر کردن داده های گمشده انجام میدم

# %%
gender_fill =df['Gender'].value_counts().index[1]
gender_fill
# Out:
# 'Female'

# %%
df['Gender'].fillna(gender_fill,inplace=True)
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
marry_fill = df['Married'].value_counts().index[1]
df['Married'].value_counts()
# Out:
# Married
# Yes    398
# No     213
# Name: count, dtype: int64

# %%
marry_fill
# Out:
# 'No'

# %%
g_notnull=[]
for i in df['Married']:
  if(i == np.nan):
    g_notnull.append(marry_fill)
  else:
    g_notnull.append(i)
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df["Married"].fillna(marry_fill,inplace=True)
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#     ApplicantIncome CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 0              5849              0.00       0.00           360.00
# ...

# %%
df2.drop(columns="Loan_ID",inplace=True)
df2
# Out:
#      Gender Married Dependents     Education Self_Employed ApplicantIncome  \
# 0      Male      No          0      Graduate            No            5849
# 1      Male     Yes          1      Graduate            No            4583
# 2      Male     Yes          0      Graduate           Yes            3000
# 3      Male     Yes          0  Not Graduate            No            2583
# 4      Male      No          0      Graduate            No            6000
# ..      ...     ...        ...           ...           ...             ...
# 609  Female      No          0      Graduate            No            2900
# 610    Male     Yes         3+      Graduate            No            4106
# 611    Male     Yes          1      Graduate            No            8072
# 612    Male     Yes          2      Graduate            No            7583
# 613  Female      No          0      Graduate           Yes            4583
#
#     CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History  \
# ...

# %%
target=df2['Loan_Status']
df2.drop(columns=["Dependents","Loan_Status"])
# Out:
#      Gender Married     Education Self_Employed ApplicantIncome  \
# 0      Male      No      Graduate            No            5849
# 1      Male     Yes      Graduate            No            4583
# 2      Male     Yes      Graduate           Yes            3000
# 3      Male     Yes  Not Graduate            No            2583
# 4      Male      No      Graduate            No            6000
# ..      ...     ...           ...           ...             ...
# 609  Female      No      Graduate            No            2900
# 610    Male     Yes      Graduate            No            4106
# 611    Male     Yes      Graduate            No            8072
# 612    Male     Yes      Graduate            No            7583
# 613  Female      No      Graduate           Yes            4583
#
#     CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History Property_Area
# 0                0.00       0.00           360.00           1.00         Urban
# ...

# %%
temp=[]
for i in target:
  if i=="Y":
    temp.append(1)
  else:
    temp.append(0)
df2["target"]=temp

# %%
temp=[]
for i in df2["Gender"]:
  if i =="Male":
    temp.append(1)
  else:
    temp.append(0)
temp[609:614]
df2["Gender"]=temp
df2
# Out:
#      Gender Married Dependents     Education Self_Employed ApplicantIncome  \
# 0         1      No          0      Graduate            No            5849
# 1         1     Yes          1      Graduate            No            4583
# 2         1     Yes          0      Graduate           Yes            3000
# 3         1     Yes          0  Not Graduate            No            2583
# 4         1      No          0      Graduate            No            6000
# ..      ...     ...        ...           ...           ...             ...
# 609       0      No          0      Graduate            No            2900
# 610       1     Yes         3+      Graduate            No            4106
# 611       1     Yes          1      Graduate            No            8072
# 612       1     Yes          2      Graduate            No            7583
# 613       0      No          0      Graduate           Yes            4583
#
#     CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History  \
# ...

# %%
temp=[]
for i in df2["Married"]:
  if i == "No":
    temp.append(0)
  else:
    temp.append(1)
temp[:5]
df2["Married"]=temp

# %%
df2
# Out:
#      Gender  Married Dependents     Education Self_Employed ApplicantIncome  \
# 0         1        0          0      Graduate            No            5849
# 1         1        1          1      Graduate            No            4583
# 2         1        1          0      Graduate           Yes            3000
# 3         1        1          0  Not Graduate            No            2583
# 4         1        0          0      Graduate            No            6000
# ..      ...      ...        ...           ...           ...             ...
# 609       0        0          0      Graduate            No            2900
# 610       1        1         3+      Graduate            No            4106
# 611       1        1          1      Graduate            No            8072
# 612       1        1          2      Graduate            No            7583
# 613       0        0          0      Graduate           Yes            4583
#
# ...

# %%
df2['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
temp=[]
for i in df2["Education"]:
  if i == "Graduate":
    temp.append(1)
  else:
    temp.append(0)
temp[:5]
df2["Education"]=temp

# %%
df2["Dependents"].value_counts()
# Out:
# Dependents
# 0         345
# 1         102
# 2         101
# 3+         51
# Yes         8
# No          4
# Male        2
# Female      1
# Name: count, dtype: int64

# %%
temp=[]
for i in df2["Dependents"]:
  if i=="0":
    temp.append(0)
  elif i =="1":
    temp.append(1)
  elif i=="2":
    temp.append(2)
  elif i=="3+":
    temp.append(4)
  elif i=="Yes":
    temp.append(1)
  elif i=="No":
    temp.append(0)
  else:
    temp.append(1)
temp[:5]
df2['Dependents']=temp

# %%
df2['Self_Employed'].value_counts()
# Out:
# Self_Employed
# No              500
# Yes              82
# Graduate         26
# Not Graduate      6
# Name: count, dtype: int64

# %%
temp=[]
for i in df2["Self_Employed"]:
  if i=="No":
    temp.append(0)
  elif i =="Yes":
    temp.append(1)
  elif i=="Graduate":
    temp.append(1)
  else:
    temp.append(0)

temp[:5]
df2["Self_Employed"]=temp

# %%
df2.drop(columns="Loan_Status",inplace=True)

# %%
df2
# Out:
#      Gender  Married  Dependents  Education  Self_Employed ApplicantIncome  \
# 0         1        0           0          1              0            5849
# 1         1        1           1          1              0            4583
# 2         1        1           0          1              1            3000
# 3         1        1           0          0              0            2583
# 4         1        0           0          1              0            6000
# ..      ...      ...         ...        ...            ...             ...
# 609       0        0           0          1              0            2900
# 610       1        1           4          1              0            4106
# 611       1        1           1          1              0            8072
# 612       1        1           2          1              0            7583
# 613       0        0           0          1              1            4583
#
#     CoapplicantIncome LoanAmount Loan_Amount_Term Credit_History  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df3 = df2
df3[['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History']]= scaler.fit_transform(df3[['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History']])

# %%
from sklearn.model_selection import train_test_split
x=df3[['Gender', 	'Married', 	'Dependents' 	,'Education' ,	'Self_Employed' ,	'ApplicantIncome' ,	'CoapplicantIncome' ,	'LoanAmount' ,	'Loan_Amount_Term', 	'Credit_History']]
y=df3['target']

# %%
df3
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          1              0             0.07
# 1         1        1           1          1              0             0.05
# 2         1        1           0          1              1             0.04
# 3         1        1           0          0              0             0.03
# 4         1        0           0          1              0             0.07
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             0.03
# 610       1        1           4          1              0             0.05
# 611       1        1           1          1              0             0.10
# 612       1        1           2          1              0             0.09
# 613       0        0           0          1              1             0.05
#
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.size
# Out:
# 4910

# %%
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(predictions=True)
models , predictions= clf.fit(x_train,x_test,y_train,y_test)
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 17.39it/s]
# [LightGBM] [Info] Number of positive: 342, number of negative: 149
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000147 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 384
# [LightGBM] [Info] Number of data points in the train set: 491, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.696538 -> initscore=0.830864
# [LightGBM] [Info] Start training from score 0.830864
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# BaggingClassifier                  0.77               0.72     0.72      0.76
# RandomForestClassifier             0.77               0.70     0.70      0.75
# XGBClassifier                      0.75               0.69     0.69      0.73
# ExtraTreesClassifier               0.76               0.68     0.68      0.74
# LGBMClassifier                     0.75               0.68     0.68      0.73
# DecisionTreeClassifier             0.72               0.68     0.68      0.72
# AdaBoostClassifier                 0.73               0.66     0.66      0.71
# ExtraTreeClassifier                0.71               0.66     0.66      0.70
# Perceptron                         0.64               0.55     0.55      0.60
# SGDClassifier                      0.59               0.53     0.53      0.58
# NuSVC                              0.64               0.52     0.52      0.56
# ...

# %%
import lightgbm as lgb
clf = lgb.LGBMClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# [LightGBM] [Info] Number of positive: 342, number of negative: 149
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 376
# [LightGBM] [Info] Number of data points in the train set: 491, number of used features: 10
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.696538 -> initscore=0.830864
# [LightGBM] [Info] Start training from score 0.830864
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
y_hat=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test,y_hat)
print(f"Accuracy: {acc:.2f}")
# Out:
# Accuracy: 0.76

# %%
from sklearn.metrics import classification_report, confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,normalize=False, title='Confusion matrix',cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_hat, labels=[0,1])
np.set_printoptions(precision=2)

print (classification_report(y_test, y_hat))

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=['pas nadade(0)','pas dade(1)'],normalize= False,  title='Confusion matrix')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.47      0.57        43
#            1       0.76      0.91      0.83        80
#
#     accuracy                           0.76       123
#    macro avg       0.75      0.69      0.70       123
# weighted avg       0.75      0.76      0.74       123
#
# Confusion matrix, without normalization
# [[20 23]
#  [ 7 73]]
